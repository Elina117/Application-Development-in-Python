# %% [markdown]
# ![Снимок экрана 2024-08-22 в 15.38.51.png](attachment:26f5236a-a9c9-483b-a7b8-a0c68b9e62c0.png)

# %% [markdown]
# **Полужирный текст**

# %% [markdown]
# *Курсивный текст*

# %% [markdown]
# Monospace

# %%
print("Hello World!")

# %% [markdown]
# ```моноширинный текст```
