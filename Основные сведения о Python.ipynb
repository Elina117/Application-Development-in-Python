# %% [markdown]
# # Основные сведения о Python

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 21.33.17.png](attachment:a2646e6c-5ab5-4590-b951-6567dd6f4ee2.png)

# %% [markdown]
# ##### Создать dictionry с данными на картинке

# %%
tasks = {
    0 : ['Покормить кота'],
    1 : ['Полить цветы','Забрать посылку'],
    2 : ['Почитать книгу по программированию'],
    3 : ['Ответить на письмо двоюродной тети']
}
print(tasks_dict)
# Out:
# {0: ['Покормить кота'], 1: ['Полить цветы', 'Забрать посылку'], 2: ['Почитать книгу по программированию'], 3: ['Ответить на письмо двоюродной тети']}

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 21.50.45.png](attachment:8d7719ba-e696-42dd-9fd4-263a5892cf75.png)

# %%
if 0 in tasks:
    print("есть срочные дела")
else:
    print("можно отдохнуть")
# Out:
# есть срочные дела

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 21.55.35.png](attachment:15a2d6ed-297d-464e-829f-d4dcd6dc7872.png)

# %%
values = []
for key, value in tasks.items():
    values.append(value)
print(values)
# Out:
# [['Покормить кота'], ['Полить цветы', 'Забрать посылку'], ['Почитать книгу по программированию'], ['Ответить на письмо двоюродной тети']]

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 22.04.44.png](attachment:68ba320e-ad43-4448-9fde-8d6e31db829f.png)

# %%
doings = []
for key, value in tasks.items():
    for val in value:
        doings.append(val)
print(doings)
# Out:
# ['Покормить кота', 'Полить цветы', 'Забрать посылку', 'Почитать книгу по программированию', 'Ответить на письмо двоюродной тети']

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 22.07.45.png](attachment:46943e02-5a56-4f1d-910b-01b996b13e86.png)

# %%
answer = []
for key, value in tasks.items():
    for val in value:
        if 'кот' in val:
            answer.append(val)
print(answer)
# Out:
# ['Покормить кота']

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 22.09.59.png](attachment:109ac144-1d1f-43d3-9fdc-1589c5db95e3.png)

# %%
answer = []

for key, value in tasks.items():
    for val in value:
        if key<2 and 'кот' in val:
            answer.append(val)
            if len(answer) >= 2:
                break
        if len(answer) >= 2:
            break
print(answer)
# Out:
# ['Покормить кота']

# %% [markdown]
# ![Снимок экрана 2024-08-14 в 22.25.33.png](attachment:7103022a-5be5-422a-b994-ac603ebd0840.png)

# %%
keys = []
values = []
for key, value in tasks.items():
    keys.append(key)
    values.append(list(set(value)))
    
new_tasks = dict(zip(keys, values))
print(new_tasks)
# Out:
# {0: ['Покормить кота'], 1: ['Полить цветы', 'Забрать посылку'], 2: ['Почитать книгу по программированию'], 3: ['Ответить на письмо двоюродной тети']}
