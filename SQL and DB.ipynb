# %% [markdown]
# ## > Как подключиться к PostgreSQL через pandas

# %% [raw]
# database="startml",
# user="robot-startml-ro",
# password="pheiph0hahj1Vaif",
# host="postgres.lab.karpov.courses",
# port=6432

# %% [markdown]
# В следующих заданиях мы будем работать с базой данных, в которой имеется три таблицы:
#
# #### 1. Таблица с данными о пользователях (user):
#
#     id - уникальный идентификатор пользователя (primary key)
#
#     gender - пол
#
#     age - возраст
#
#     country - страна
#
#     city - город
#
#     exp_group - экспериментальная группа
#
#     os - операционная система
#
#     source - источник трафика
#
# #### 2. Таблица с данными о постах (post):
#
#     id - уникальный идентификатор поста (primary key)
#
#     text - текст поста
#
#     topic - тема поста
#
# #### 3. Таблица с данными о действиях пользователей (feed_action):
#
#     user_id (——>) user (id)- идентификатор пользователя
#
#     post_id (——>) post (id)- идентификатор поста
#
#     action - совершенное в сети действие
#
#     time- время действия

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 18.41.45.png](attachment:1475e9b2-4e11-47f9-9736-b85d085c0989.png)

# %%
import psycopg2 as ps
import pandas as pd

connection = ps.connect(
    database="startml",
    user="robot-startml-ro",
    password="pheiph0hahj1Vaif",
    host="postgres.lab.karpov.courses",
    port=6432
)
cursor = connection.cursor()

cursor.execute(
    """
    SELECT *
    FROM "user"
    ORDER BY id
    LIMIT 1;
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# (200, 1, 34, 'Russia', 'Degtyarsk', 3, 'Android', 'ads')

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.01.05.png](attachment:3b2ee810-4ca1-442e-9caa-e4b23055d724.png)

# %%
cursor.execute(
    """
    SELECT DISTINCT topic
    FROM post
    """)
result = cursor.fetchall()

for row in result:
    print(row)
len(result)
# Out:
# ('tech',)
# ('covid',)
# ('movie',)
# ('entertainment',)
# ('politics',)
# ('sport',)
# ('business',)
# 7

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.08.47.png](attachment:d92afd15-26ad-44af-8ea4-e14d25f4183b.png)

# %%
cursor.execute(
    """
    SELECT *
    FROM "user"
    WHERE os = 'iOS' AND age>'30'
    LIMIT 1;
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# (212, 1, 47, 'Russia', 'Podolsk', 0, 'iOS', 'ads')

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.15.46.png](attachment:bcbf7145-18aa-4f70-bb91-d783c6ceeba3.png)

# %%
cursor.execute(
    """
    SELECT *
    FROM "user"
    WHERE country != 'Russia'
    AND (exp_group NOT IN (0, 3)) OR city = 'Minsk'
    LIMIT 4;
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# (211, 1, 22, 'Belarus', 'Minsk', 0, 'iOS', 'ads')
# (213, 1, 22, 'Ukraine', 'Kamianske', 2, 'iOS', 'ads')
# (216, 0, 38, 'Ukraine', 'Lviv', 1, 'Android', 'ads')
# (218, 1, 25, 'Belarus', 'Minsk', 2, 'iOS', 'ads')

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.30.38.png](attachment:a5c49ac3-ceeb-4047-b041-27114b0e0ebe.png)

# %%
cursor.execute(
    """
    SELECT AVG(age) as age
    FROM "user"
    WHERE country = 'Cyprus'
    LIMIT 4;
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# (Decimal('28.0705882352941176'),)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.37.12.png](attachment:2067d2de-d8c0-4fbf-9b0b-d49a3e155d54.png)

# %%
cursor.execute(
    """
    SELECT 
        exp_group,
        os,
        COUNT(*) AS user_count,
        MAX(age) AS max_age,
        MIN(age) AS min_age
    FROM "user"
    GROUP BY exp_group, os
    ORDER BY exp_group, os;
    """)
result = cursor.fetchall()
df = pd.DataFrame(result, columns=['exp_group','os','total_users','max_age','min_age'])
df.to_csv('exp_group.csv', sep=',', index=False)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 19.48.24.png](attachment:1dd138b5-47eb-48a4-8421-19a93144f133.png)

# %%
cursor.execute(
    """
     SELECT topic
        FROM post
        GROUP BY topic
        HAVING MAX(LENGTH(text)) > 25000;
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# ('politics',)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 20.00.21.png](attachment:344b81b2-0bda-4fd2-8b72-c352eb96825b.png)

# %%
cursor.execute(
    """
    SELECT country, COUNT(*) AS user_count
    FROM "user"
    GROUP BY country
    HAVING COUNT(*)>1000
    ORDER BY user_count
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# ('Azerbaijan', 1542)
# ('Finland', 1599)
# ('Turkey', 1606)
# ('Kazakhstan', 3172)
# ('Belarus', 3293)
# ('Ukraine', 8273)
# ('Russia', 143035)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 20.07.46.png](attachment:03d05baa-0c9a-4ab2-8c52-2990ad3b5cd1.png)

# %%
cursor.execute(
    """
    SELECT exp_group, AVG(age) as age, COUNT(*) AS user_count
    FROM "user"
    WHERE city = 'Moscow'
    GROUP BY exp_group
    HAVING AVG(age)>27.2
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# (1, Decimal('27.3251019483461713'), 4414)
# (3, Decimal('27.3142987665600731'), 4378)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 20.13.26.png](attachment:87c95057-bf19-445f-9bfc-79eb899dbe56.png)

# %%
cursor.execute(
    """
    SELECT topic, COUNT(*) as post_count
    FROM post
    GROUP BY topic
    ORDER BY post_count DESC
    """)
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# ('movie', 3000)
# ('covid', 1799)
# ('business', 510)
# ('sport', 510)
# ('politics', 417)
# ('tech', 401)
# ('entertainment', 386)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 20.17.08.png](attachment:e57ba660-3295-43e8-820a-aa581d8d306f.png)

# %%
cursor.execute(
    """
    SELECT id
    FROM "user"
    WHERE city = 'Voronezh'
    ORDER BY age DESC, exp_group ASC
    LIMIT 2;
    """)
result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# (89990,)
# (2441,)

# %% [markdown]
# ![Снимок экрана 2024-08-27 в 20.22.14.png](attachment:d9b7063f-95ca-424f-b8c2-c924ccb0a62b.png)

# %%
# Выполняем SQL-запрос
cursor.execute(
    """
    SELECT p.id AS post_id, f.time AS time, u.age AS age, u.os AS os
    FROM "user" u
    JOIN "feed_action" f ON f.user_id = u.id
    JOIN "post" p ON  p.id = f.post_id
    WHERE u.city = 'Omsk' AND f.action = 'like'
    ORDER BY f.time DESC
    LIMIT 100;
    """
)

# Извлекаем все результаты
result = cursor.fetchall()
df = pd.DataFrame(result, columns=['post_id','time','age','os'])
df.to_csv('post_id.csv', sep=',', index=False)
for row in result:
    print(row)
# Out:
# (7159, datetime.datetime(2022, 1, 26, 23, 59, 54), 17, 'Android')
# (7184, datetime.datetime(2022, 1, 26, 23, 56, 30), 17, 'Android')
# (7265, datetime.datetime(2022, 1, 26, 23, 56, 3), 17, 'Android')
# (7256, datetime.datetime(2022, 1, 26, 23, 55, 24), 17, 'Android')
# (7080, datetime.datetime(2022, 1, 26, 23, 55, 12), 17, 'Android')
# (7163, datetime.datetime(2022, 1, 26, 23, 54, 36), 20, 'iOS')
# (7174, datetime.datetime(2022, 1, 26, 23, 54, 29), 20, 'iOS')
# (7315, datetime.datetime(2022, 1, 26, 23, 54, 28), 20, 'iOS')
# (7280, datetime.datetime(2022, 1, 26, 23, 54, 19), 22, 'Android')
# (6943, datetime.datetime(2022, 1, 26, 23, 52, 29), 20, 'iOS')
# (7242, datetime.datetime(2022, 1, 26, 23, 52, 1), 20, 'iOS')
# (7192, datetime.datetime(2022, 1, 26, 23, 51, 36), 22, 'Android')
# (7251, datetime.datetime(2022, 1, 26, 23, 50, 50), 22, 'Android')
# (7184, datetime.datetime(2022, 1, 26, 23, 50, 42), 20, 'iOS')
# (7168, datetime.datetime(2022, 1, 26, 23, 50, 7), 22, 'Android')
# (7213, datetime.datetime(2022, 1, 26, 23, 49, 1), 41, 'iOS')
# (7257, datetime.datetime(2022, 1, 26, 23, 49), 36, 'iOS')
# (7137, datetime.datetime(2022, 1, 26, 23, 48, 48), 41, 'iOS')
# (7256, datetime.datetime(2022, 1, 26, 23, 48, 45), 36, 'iOS')
# (7003, datetime.datetime(2022, 1, 26, 23, 48, 40), 36, 'iOS')
# (7175, datetime.datetime(2022, 1, 26, 23, 48, 39), 36, 'iOS')
# (7272, datetime.datetime(2022, 1, 26, 23, 48, 17), 36, 'iOS')
# (7244, datetime.datetime(2022, 1, 26, 23, 47, 4), 41, 'iOS')
# (7125, datetime.datetime(2022, 1, 26, 23, 45, 58), 36, 'iOS')
# (7283, datetime.datetime(2022, 1, 26, 23, 45), 41, 'iOS')
# (7292, datetime.datetime(2022, 1, 26, 23, 44, 56), 29, 'Android')
# (7259, datetime.datetime(2022, 1, 26, 23, 44, 43), 29, 'Android')
# (6943, datetime.datetime(2022, 1, 26, 23, 44, 43), 53, 'iOS')
# (7202, datetime.datetime(2022, 1, 26, 23, 44, 41), 29, 'Android')
# (7264, datetime.datetime(2022, 1, 26, 23, 44, 12), 53, 'iOS')
# (7208, datetime.datetime(2022, 1, 26, 23, 43, 21), 53, 'iOS')
# (7174, datetime.datetime(2022, 1, 26, 23, 43, 1), 53, 'iOS')
# (7260, datetime.datetime(2022, 1, 26, 23, 42, 49), 53, 'iOS')
# (7285, datetime.datetime(2022, 1, 26, 23, 42, 30), 53, 'iOS')
# (7204, datetime.datetime(2022, 1, 26, 23, 42, 3), 53, 'iOS')
# (7157, datetime.datetime(2022, 1, 26, 23, 41, 41), 29, 'Android')
# (7268, datetime.datetime(2022, 1, 26, 23, 41, 14), 53, 'iOS')
# (7059, datetime.datetime(2022, 1, 26, 23, 41, 2), 29, 'Android')
# (7256, datetime.datetime(2022, 1, 26, 23, 40, 32), 53, 'iOS')
# (7226, datetime.datetime(2022, 1, 26, 23, 39, 39), 39, 'Android')
# (7309, datetime.datetime(2022, 1, 26, 23, 39, 38), 21, 'Android')
# (7159, datetime.datetime(2022, 1, 26, 23, 39, 37), 39, 'Android')
# (7249, datetime.datetime(2022, 1, 26, 23, 39, 29), 21, 'Android')
# (7003, datetime.datetime(2022, 1, 26, 23, 39, 22), 21, 'Android')
# (7097, datetime.datetime(2022, 1, 26, 23, 39, 5), 39, 'Android')
# (7274, datetime.datetime(2022, 1, 26, 23, 38, 55), 39, 'Android')
# (7217, datetime.datetime(2022, 1, 26, 23, 38, 51), 21, 'Android')
# (7003, datetime.datetime(2022, 1, 26, 23, 38, 38), 40, 'iOS')
# (7303, datetime.datetime(2022, 1, 26, 23, 38, 23), 21, 'Android')
# (7125, datetime.datetime(2022, 1, 26, 23, 38, 12), 45, 'Android')
# (7299, datetime.datetime(2022, 1, 26, 23, 38, 4), 21, 'Android')
# (7180, datetime.datetime(2022, 1, 26, 23, 37, 51), 32, 'Android')
# (7306, datetime.datetime(2022, 1, 26, 23, 37, 37), 39, 'Android')
# (7294, datetime.datetime(2022, 1, 26, 23, 37, 29), 21, 'Android')
# (7254, datetime.datetime(2022, 1, 26, 23, 37, 27), 32, 'Android')
# (7303, datetime.datetime(2022, 1, 26, 23, 37, 25), 45, 'Android')
# (7159, datetime.datetime(2022, 1, 26, 23, 37, 12), 21, 'Android')
# (7272, datetime.datetime(2022, 1, 26, 23, 36, 47), 39, 'Android')
# (7080, datetime.datetime(2022, 1, 26, 23, 36, 7), 21, 'Android')
# (7294, datetime.datetime(2022, 1, 26, 23, 35, 44), 32, 'Android')
# (7244, datetime.datetime(2022, 1, 26, 23, 35, 35), 45, 'Android')
# (7204, datetime.datetime(2022, 1, 26, 23, 34, 44), 16, 'iOS')
# (6957, datetime.datetime(2022, 1, 26, 23, 33, 56), 16, 'iOS')
# (7283, datetime.datetime(2022, 1, 26, 23, 33, 11), 16, 'iOS')
# (7085, datetime.datetime(2022, 1, 26, 23, 32, 10), 16, 'iOS')
# (7277, datetime.datetime(2022, 1, 26, 23, 31, 17), 16, 'iOS')
# (7302, datetime.datetime(2022, 1, 26, 23, 30, 5), 16, 'iOS')
# (7164, datetime.datetime(2022, 1, 26, 23, 21, 48), 73, 'iOS')
# (7115, datetime.datetime(2022, 1, 26, 23, 21, 8), 73, 'iOS')
# (7159, datetime.datetime(2022, 1, 26, 23, 20, 37), 73, 'iOS')
# (7157, datetime.datetime(2022, 1, 26, 23, 14, 57), 39, 'Android')
# (7198, datetime.datetime(2022, 1, 26, 23, 14, 56), 46, 'iOS')
# (7185, datetime.datetime(2022, 1, 26, 23, 13, 2), 46, 'iOS')
# (7164, datetime.datetime(2022, 1, 26, 23, 11, 49), 39, 'Android')
# (7299, datetime.datetime(2022, 1, 26, 23, 10, 50), 46, 'iOS')
# (7168, datetime.datetime(2022, 1, 26, 23, 10, 30), 46, 'iOS')
# (7283, datetime.datetime(2022, 1, 26, 23, 10, 24), 39, 'Android')
# (7251, datetime.datetime(2022, 1, 26, 23, 8, 30), 32, 'Android')
# (7268, datetime.datetime(2022, 1, 26, 22, 59, 46), 22, 'Android')
# (7157, datetime.datetime(2022, 1, 26, 22, 59, 11), 31, 'iOS')
# (7317, datetime.datetime(2022, 1, 26, 22, 58, 50), 34, 'Android')
# (7286, datetime.datetime(2022, 1, 26, 22, 58, 6), 34, 'Android')
# (7292, datetime.datetime(2022, 1, 26, 22, 58, 4), 34, 'Android')
# (7283, datetime.datetime(2022, 1, 26, 22, 57, 49), 22, 'Android')
# (7283, datetime.datetime(2022, 1, 26, 22, 57, 43), 34, 'Android')
# (7191, datetime.datetime(2022, 1, 26, 22, 56, 26), 31, 'iOS')
# (7226, datetime.datetime(2022, 1, 26, 22, 56, 19), 22, 'Android')
# (7059, datetime.datetime(2022, 1, 26, 22, 55, 41), 22, 'Android')
# (7238, datetime.datetime(2022, 1, 26, 22, 55, 25), 34, 'Android')
# (7272, datetime.datetime(2022, 1, 26, 22, 55, 4), 31, 'iOS')
# (7294, datetime.datetime(2022, 1, 26, 22, 48, 58), 22, 'Android')
# (7184, datetime.datetime(2022, 1, 26, 22, 45, 23), 22, 'Android')
# (7087, datetime.datetime(2022, 1, 26, 22, 44, 49), 31, 'Android')
# (7125, datetime.datetime(2022, 1, 26, 22, 44, 1), 31, 'Android')
# (7272, datetime.datetime(2022, 1, 26, 22, 44), 31, 'Android')
# (7256, datetime.datetime(2022, 1, 26, 22, 43, 54), 31, 'Android')
# (7316, datetime.datetime(2022, 1, 26, 22, 42, 54), 31, 'Android')
# (7319, datetime.datetime(2022, 1, 26, 22, 39, 35), 36, 'iOS')
# (7268, datetime.datetime(2022, 1, 26, 22, 39, 4), 36, 'iOS')
# (7226, datetime.datetime(2022, 1, 26, 22, 35, 11), 36, 'iOS')

# %% [markdown]
# ![Снимок экрана 2024-08-28 в 14.17.42.png](attachment:d94cc024-e2cb-4e09-9469-9e851e8f6353.png)

# %% [markdown]
# 1) Выбираем город и подсчитываем его кол-во просмотров
# 2) Используем таблицу user
# 3) Соединяем необходимые таблицы
# 4) Выставляем все условия
# 5) Группируем по городу
# 6) Фильтруем по кол-ву просмотров

# %%
cursor.execute(
    """
    SELECT u.city, COUNT(*) AS view_count
    FROM "user" u
    JOIN "feed_action" f ON f.user_id = u.id
    JOIN "post" p ON p.id = f.post_id
    WHERE u.age = '36' 
      AND f.time::date = '2021-12-01' 
      AND p.topic = 'covid' 
      AND f.action = 'view'
    GROUP BY u.city
    ORDER BY view_count ASC
    LIMIT 1;

    """
)## есть условие, которое игнорирует время

# Извлекаем все результаты
result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# ('Arkhangelsk', 5)

# %% [markdown]
# ![Снимок экрана 2024-08-28 в 14.42.06.png](attachment:e338b180-b090-4ad5-91bc-f4c2952b9d7e.png)

# %%
cursor.execute(
    """
    SELECT 
        p.id AS post_id,
        COUNT(f.user_id) AS like_count, 
        COUNT(DISTINCT f.user_id) uniq_like,
        MAX(f.time) last_like_time
    FROM "feed_action" f 
    JOIN "post" p ON p.id = f.post_id
    WHERE f.action = 'like'
    GROUP BY p.id
    ORDER BY like_count DESC
    LIMIT 3;

    """
)## есть условие, которое игнорирует время

# Извлекаем все результаты
result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# (4866, 31714, 31714, datetime.datetime(2022, 1, 1, 13, 57, 43))
# (5127, 29637, 29637, datetime.datetime(2022, 1, 5, 13, 52, 17))
# (6448, 27939, 27939, datetime.datetime(2022, 1, 22, 5, 50, 39))
